# %%
# -----import excel file-----

# %%
import pandas as pd
df_cars=pd.read_csv(r"C:\jayasri\CarPrice_Assignment.csv")
df_cars
# Out:
#      car_ID  symboling                   CarName fueltype aspiration  \
# 0         1          3        alfa-romero giulia      gas        std
# 1         2          3       alfa-romero stelvio      gas        std
# 2         3          1  alfa-romero Quadrifoglio      gas        std
# 3         4          2               audi 100 ls      gas        std
# 4         5          2                audi 100ls      gas        std
# ..      ...        ...                       ...      ...        ...
# 200     201         -1           volvo 145e (sw)      gas        std
# 201     202         -1               volvo 144ea      gas      turbo
# 202     203         -1               volvo 244dl      gas        std
# 203     204         -1                 volvo 246   diesel      turbo
# 204     205         -1               volvo 264gl      gas      turbo
#
#     doornumber      carbody drivewheel enginelocation  wheelbase  ...  \
# ...

# %%
# df_cars.cylindernumber.unique()

# %%
# ---------basic checks------

# %%
df_cars.head()
# Out:
#    car_ID  symboling                   CarName fueltype aspiration doornumber  \
# 0       1          3        alfa-romero giulia      gas        std        two
# 1       2          3       alfa-romero stelvio      gas        std        two
# 2       3          1  alfa-romero Quadrifoglio      gas        std        two
# 3       4          2               audi 100 ls      gas        std       four
# 4       5          2                audi 100ls      gas        std       four
#
#        carbody drivewheel enginelocation  wheelbase  ...  enginesize  \
# 0  convertible        rwd          front       88.6  ...         130
# 1  convertible        rwd          front       88.6  ...         130
# 2    hatchback        rwd          front       94.5  ...         152
# 3        sedan        fwd          front       99.8  ...         109
# 4        sedan        4wd          front       99.4  ...         136
#
#    fuelsystem  boreratio  stroke compressionratio horsepower  peakrpm citympg  \
# ...

# %%
df_cars.tail()
# Out:
#      car_ID  symboling          CarName fueltype aspiration doornumber  \
# 200     201         -1  volvo 145e (sw)      gas        std       four
# 201     202         -1      volvo 144ea      gas      turbo       four
# 202     203         -1      volvo 244dl      gas        std       four
# 203     204         -1        volvo 246   diesel      turbo       four
# 204     205         -1      volvo 264gl      gas      turbo       four
#
#     carbody drivewheel enginelocation  wheelbase  ...  enginesize  fuelsystem  \
# 200   sedan        rwd          front      109.1  ...         141        mpfi
# 201   sedan        rwd          front      109.1  ...         141        mpfi
# 202   sedan        rwd          front      109.1  ...         173        mpfi
# 203   sedan        rwd          front      109.1  ...         145         idi
# 204   sedan        rwd          front      109.1  ...         141        mpfi
#
# ...

# %%
df_cars.shape
# Out:
# (205, 26)

# %%
df_cars.columns
# Out:
# Index(['car_ID', 'symboling', 'CarName', 'fueltype', 'aspiration',
#        'doornumber', 'carbody', 'drivewheel', 'enginelocation', 'wheelbase',
#        'carlength', 'carwidth', 'carheight', 'curbweight', 'enginetype',
#        'cylindernumber', 'enginesize', 'fuelsystem', 'boreratio', 'stroke',
#        'compressionratio', 'horsepower', 'peakrpm', 'citympg', 'highwaympg',
#        'price'],
#       dtype='object')

# %%
df_cars.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   car_ID            205 non-null    int64
#  1   symboling         205 non-null    int64
#  2   CarName           205 non-null    object
#  3   fueltype          205 non-null    object
#  4   aspiration        205 non-null    object
#  5   doornumber        205 non-null    object
#  6   carbody           205 non-null    object
#  7   drivewheel        205 non-null    object
#  8   enginelocation    205 non-null    object
#  9   wheelbase         205 non-null    float64
#  10  carlength         205 non-null    float64
#  11  carwidth          205 non-null    float64
#  12  carheight         205 non-null    float64
#  13  curbweight        205 non-null    int64
#  14  enginetype        205 non-null    object
#  15  cylindernumber    205 non-null    object
# ...

# %%
df_cars.dtypes
# Out:
# car_ID                int64
# symboling             int64
# CarName              object
# fueltype             object
# aspiration           object
# doornumber           object
# carbody              object
# drivewheel           object
# enginelocation       object
# wheelbase           float64
# carlength           float64
# carwidth            float64
# carheight           float64
# curbweight            int64
# enginetype           object
# cylindernumber       object
# enginesize            int64
# fuelsystem           object
# boreratio           float64
# stroke              float64
# compressionratio    float64
# horsepower            int64
# peakrpm               int64
# citympg               int64
# highwaympg            int64
# price               float64
# dtype: object

# %%
type(df_cars)
# Out:
# pandas.core.frame.DataFrame

# %%
df_cars.index
# Out:
# RangeIndex(start=0, stop=205, step=1)

# %%
#---using isnull ------

# %%
df_cars.isnull()
# Out:
#      car_ID  symboling  CarName  fueltype  aspiration  doornumber  carbody  \
# 0     False      False    False     False       False       False    False
# 1     False      False    False     False       False       False    False
# 2     False      False    False     False       False       False    False
# 3     False      False    False     False       False       False    False
# 4     False      False    False     False       False       False    False
# ..      ...        ...      ...       ...         ...         ...      ...
# 200   False      False    False     False       False       False    False
# 201   False      False    False     False       False       False    False
# 202   False      False    False     False       False       False    False
# 203   False      False    False     False       False       False    False
# 204   False      False    False     False       False       False    False
#
# ...

# %%
#----using fillna----

# %%
df_cars.fillna(0)
# Out:
#      car_ID  symboling                   CarName fueltype aspiration  \
# 0         1          3        alfa-romero giulia      gas        std
# 1         2          3       alfa-romero stelvio      gas        std
# 2         3          1  alfa-romero Quadrifoglio      gas        std
# 3         4          2               audi 100 ls      gas        std
# 4         5          2                audi 100ls      gas        std
# ..      ...        ...                       ...      ...        ...
# 200     201         -1           volvo 145e (sw)      gas        std
# 201     202         -1               volvo 144ea      gas      turbo
# 202     203         -1               volvo 244dl      gas        std
# 203     204         -1                 volvo 246   diesel      turbo
# 204     205         -1               volvo 264gl      gas      turbo
#
#     doornumber      carbody drivewheel enginelocation  wheelbase  ...  \
# ...

# %%
df_cars.columns
# Out:
# Index(['car_ID', 'symboling', 'CarName', 'fueltype', 'aspiration',
#        'doornumber', 'carbody', 'drivewheel', 'enginelocation', 'wheelbase',
#        'carlength', 'carwidth', 'carheight', 'curbweight', 'enginetype',
#        'cylindernumber', 'enginesize', 'fuelsystem', 'boreratio', 'stroke',
#        'compressionratio', 'horsepower', 'peakrpm', 'citympg', 'highwaympg',
#        'price'],
#       dtype='object')

# %%
#-----1-----select only bmw, audi,nissan-----------------------

# %%
df_cars[df_cars["CarName"].isin(['bmw 320i','bmw x1','bmw x2','bmw x3','bmw x4','bmw z4','bmw x5','audi 100 ls','audi 100ls','audi fox','audi 5000','audi 4000','audi 5000s (diesel)','Nissan versa','nissan gt-r','nissan rogue','nissan latio','nissan titan','nissan leaf','nissan juke','nissan latio','nissan note','nissan clipper','nissan rogue','nissan nv200','nissan dayz','nissan fuga','nissan otti','nissan teana','nissan kicks','nissan clipper'])]
# Out:
#      car_ID  symboling              CarName fueltype aspiration doornumber  \
# 3         4          2          audi 100 ls      gas        std       four
# 4         5          2           audi 100ls      gas        std       four
# 5         6          2             audi fox      gas        std        two
# 6         7          1           audi 100ls      gas        std       four
# 7         8          1            audi 5000      gas        std       four
# 8         9          1            audi 4000      gas      turbo       four
# 9        10          0  audi 5000s (diesel)      gas      turbo        two
# 10       11          2             bmw 320i      gas        std        two
# 11       12          0             bmw 320i      gas        std       four
# 12       13          0               bmw x1      gas        std        two
# 13       14          0               bmw x3      gas        std       four
# ...

# %%
df_cars_fil=pd.DataFrame(df_cars)

# %%
df_cars_fil
# Out:
#      car_ID  symboling                   CarName fueltype aspiration  \
# 0         1          3        alfa-romero giulia      gas        std
# 1         2          3       alfa-romero stelvio      gas        std
# 2         3          1  alfa-romero Quadrifoglio      gas        std
# 3         4          2               audi 100 ls      gas        std
# 4         5          2                audi 100ls      gas        std
# ..      ...        ...                       ...      ...        ...
# 200     201         -1           volvo 145e (sw)      gas        std
# 201     202         -1               volvo 144ea      gas      turbo
# 202     203         -1               volvo 244dl      gas        std
# 203     204         -1                 volvo 246   diesel      turbo
# 204     205         -1               volvo 264gl      gas      turbo
#
#     doornumber      carbody drivewheel enginelocation  wheelbase  ...  \
# ...

# %%
#---2------overall price----------

# %%
df_cars_fil[["CarName","price"]]
# Out:
#                       CarName    price
# 0          alfa-romero giulia  13495.0
# 1         alfa-romero stelvio  16500.0
# 2    alfa-romero Quadrifoglio  16500.0
# 3                 audi 100 ls  13950.0
# 4                  audi 100ls  17450.0
# ..                        ...      ...
# 200           volvo 145e (sw)  16845.0
# 201               volvo 144ea  19045.0
# 202               volvo 244dl  21485.0
# 203                 volvo 246  22470.0
# 204               volvo 264gl  22625.0
#
# [205 rows x 2 columns]

# %%
#--3----fuel_system $ price

# %%
df_cars_fil[['fuelsystem','price']]
# Out:
#     fuelsystem    price
# 0         mpfi  13495.0
# 1         mpfi  16500.0
# 2         mpfi  16500.0
# 3         mpfi  13950.0
# 4         mpfi  17450.0
# ..         ...      ...
# 200       mpfi  16845.0
# 201       mpfi  19045.0
# 202       mpfi  21485.0
# 203        idi  22470.0
# 204       mpfi  22625.0
#
# [205 rows x 2 columns]

# %%
#-4---car body , fuel_system $ price

# %%
df_cars_fil[['carbody','fuelsystem','price']]
# Out:
#          carbody fuelsystem    price
# 0    convertible       mpfi  13495.0
# 1    convertible       mpfi  16500.0
# 2      hatchback       mpfi  16500.0
# 3          sedan       mpfi  13950.0
# 4          sedan       mpfi  17450.0
# ..           ...        ...      ...
# 200        sedan       mpfi  16845.0
# 201        sedan       mpfi  19045.0
# 202        sedan       mpfi  21485.0
# 203        sedan        idi  22470.0
# 204        sedan       mpfi  22625.0
#
# [205 rows x 3 columns]

# %%
#--5---		carbody	fuelsystem 	compressionratio-overall	horsepower-overall	peakrpm-overall	citympg-overall	highwaympg-overall	price-overall

# %%
df_cars_fil.columns
# Out:
# Index(['car_ID', 'symboling', 'CarName', 'fueltype', 'aspiration',
#        'doornumber', 'carbody', 'drivewheel', 'enginelocation', 'wheelbase',
#        'carlength', 'carwidth', 'carheight', 'curbweight', 'enginetype',
#        'cylindernumber', 'enginesize', 'fuelsystem', 'boreratio', 'stroke',
#        'compressionratio', 'horsepower', 'peakrpm', 'citympg', 'highwaympg',
#        'price'],
#       dtype='object')

# %%
df_cars_fil[['carbody','fuelsystem','compressionratio','horsepower','peakrpm','citympg','highwaympg','price']]
# Out:
#          carbody fuelsystem  compressionratio  horsepower  peakrpm  citympg  \
# 0    convertible       mpfi               9.0         111     5000       21
# 1    convertible       mpfi               9.0         111     5000       21
# 2      hatchback       mpfi               9.0         154     5000       19
# 3          sedan       mpfi              10.0         102     5500       24
# 4          sedan       mpfi               8.0         115     5500       18
# ..           ...        ...               ...         ...      ...      ...
# 200        sedan       mpfi               9.5         114     5400       23
# 201        sedan       mpfi               8.7         160     5300       19
# 202        sedan       mpfi               8.8         134     5500       18
# 203        sedan        idi              23.0         106     4800       26
# 204        sedan       mpfi               9.5         114     5400       19
#
#      highwaympg    price
# 0            27  13495.0
# ...

# %%
#----6----			enginetype	cylindernumber	enginesize	fuelsystem	boreratio	stroke	compressionratio	horsepower	peakrpm	citympg	highwaympg	price

# %%
df_cars_fil.columns
# Out:
# Index(['car_ID', 'symboling', 'CarName', 'fueltype', 'aspiration',
#        'doornumber', 'carbody', 'drivewheel', 'enginelocation', 'wheelbase',
#        'carlength', 'carwidth', 'carheight', 'curbweight', 'enginetype',
#        'cylindernumber', 'enginesize', 'fuelsystem', 'boreratio', 'stroke',
#        'compressionratio', 'horsepower', 'peakrpm', 'citympg', 'highwaympg',
#        'price'],
#       dtype='object')

# %%
df_cars_fil[['enginetype','cylindernumber','enginesize','fuelsystem','boreratio','stroke','compressionratio','horsepower','peakrpm','citympg','highwaympg','price']]
# Out:
#     enginetype cylindernumber  enginesize fuelsystem  boreratio  stroke  \
# 0         dohc           four         130       mpfi       3.47    2.68
# 1         dohc           four         130       mpfi       3.47    2.68
# 2         ohcv            six         152       mpfi       2.68    3.47
# 3          ohc           four         109       mpfi       3.19    3.40
# 4          ohc           five         136       mpfi       3.19    3.40
# ..         ...            ...         ...        ...        ...     ...
# 200        ohc           four         141       mpfi       3.78    3.15
# 201        ohc           four         141       mpfi       3.78    3.15
# 202       ohcv            six         173       mpfi       3.58    2.87
# 203        ohc            six         145        idi       3.01    3.40
# 204        ohc           four         141       mpfi       3.78    3.15
#
#      compressionratio  horsepower  peakrpm  citympg  highwaympg    price
# ...

# %%
df_cars_fil.cylindernumber.unique()
# Out:
# array(['four', 'six', 'five', 'three', 'twelve', 'two', 'eight'],
#       dtype=object)

# %%
#--***  7--A-----select only combination of enginetype ohc and cylindernumber one,two,three,four,five,six
# 			enginetype	cylindernumber	enginesize	fuelsystem	boreratio	stroke	compressionratio	horsepower	peakrpm	citympg	highwaympg	price

# %%
# df = df[df[['team', 'position']].isin(['A', 'Guard']).any(axis=1)]

# %%
df_eng_cyl=df_cars[df_cars[['cylindernumber','enginetype']].isin(['one','two','three','four','five','six','ohc']).any(axis=1)]
df_eng_cyl
# Out:
#      car_ID  symboling                   CarName fueltype aspiration  \
# 0         1          3        alfa-romero giulia      gas        std
# 1         2          3       alfa-romero stelvio      gas        std
# 2         3          1  alfa-romero Quadrifoglio      gas        std
# 3         4          2               audi 100 ls      gas        std
# 4         5          2                audi 100ls      gas        std
# ..      ...        ...                       ...      ...        ...
# 200     201         -1           volvo 145e (sw)      gas        std
# 201     202         -1               volvo 144ea      gas      turbo
# 202     203         -1               volvo 244dl      gas        std
# 203     204         -1                 volvo 246   diesel      turbo
# 204     205         -1               volvo 264gl      gas      turbo
#
#     doornumber      carbody drivewheel enginelocation  wheelbase  ...  \
# ...

# %%
df_eng_cyl.cylindernumber.unique()
# Out:
# array(['four', 'six', 'five', 'three', 'two'], dtype=object)

# %%
df_eng_cyl[['enginetype','cylindernumber','enginesize','fuelsystem','boreratio','stroke','compressionratio','horsepower','peakrpm','citympg','highwaympg','price']]
# Out:
#     enginetype cylindernumber  enginesize fuelsystem  boreratio  stroke  \
# 0         dohc           four         130       mpfi       3.47    2.68
# 1         dohc           four         130       mpfi       3.47    2.68
# 2         ohcv            six         152       mpfi       2.68    3.47
# 3          ohc           four         109       mpfi       3.19    3.40
# 4          ohc           five         136       mpfi       3.19    3.40
# ..         ...            ...         ...        ...        ...     ...
# 200        ohc           four         141       mpfi       3.78    3.15
# 201        ohc           four         141       mpfi       3.78    3.15
# 202       ohcv            six         173       mpfi       3.58    2.87
# 203        ohc            six         145        idi       3.01    3.40
# 204        ohc           four         141       mpfi       3.78    3.15
#
#      compressionratio  horsepower  peakrpm  citympg  highwaympg    price
# ...

# %%
df_eng_cyl.cylindernumber.unique()
# Out:
# array(['four', 'six', 'five', 'three', 'two'], dtype=object)

# %%
#-----7-----B------select only combination of enginetype ohc and cylindernumber one

# %%
df1=df_cars_fil[(df_cars_fil['enginetype']=='ohc') & (df_cars_fil['cylindernumber']=='one')]
df1
# Out:
# Empty DataFrame
# Columns: [car_ID, symboling, CarName, fueltype, aspiration, doornumber, carbody, drivewheel, enginelocation, wheelbase, carlength, carwidth, carheight, curbweight, enginetype, cylindernumber, enginesize, fuelsystem, boreratio, stroke, compressionratio, horsepower, peakrpm, citympg, highwaympg, price]
# Index: []
#
# [0 rows x 26 columns]

# %%
df1.cylindernumber.unique
# Out:
# <bound method Series.unique of Series([], Name: cylindernumber, dtype: object)>

# %%
#  			enginetype	cylindernumber	enginesize	fuelsystem	boreratio	stroke	compressionratio	horsepower	peakrpm	citympg	highwaympg	price

# %%
df1[['enginetype','cylindernumber','enginesize','fuelsystem','boreratio','stroke','compressionratio','horsepower','peakrpm','citympg','highwaympg','price']]
# Out:
# Empty DataFrame
# Columns: [enginetype, cylindernumber, enginesize, fuelsystem, boreratio, stroke, compressionratio, horsepower, peakrpm, citympg, highwaympg, price]
# Index: []

# %%
df1.cylindernumber.unique()
# Out:
# array([], dtype=object)

# %%
#--------8------do group by=---------
# 			enginelocation	enginetype	cylindernumber	price--overall price

# %%
# *********  9 ************
# Filter this data
# cylindernumber	enginesize	fuelsystem	boreratio	stroke	compressionratio	horsepower	peakrpm	citympg	highwaympg	price

# %%
df_cars_fil[['cylindernumber','enginesize','fuelsystem','boreratio','stroke','compressionratio','horsepower','peakrpm','citympg','highwaympg','price']]
# Out:
#     cylindernumber  enginesize fuelsystem  boreratio  stroke  \
# 0             four         130       mpfi       3.47    2.68
# 1             four         130       mpfi       3.47    2.68
# 2              six         152       mpfi       2.68    3.47
# 3             four         109       mpfi       3.19    3.40
# 4             five         136       mpfi       3.19    3.40
# ..             ...         ...        ...        ...     ...
# 200           four         141       mpfi       3.78    3.15
# 201           four         141       mpfi       3.78    3.15
# 202            six         173       mpfi       3.58    2.87
# 203            six         145        idi       3.01    3.40
# 204           four         141       mpfi       3.78    3.15
#
#      compressionratio  horsepower  peakrpm  citympg  highwaympg    price
# 0                 9.0         111     5000       21          27  13495.0
# 1                 9.0         111     5000       21          27  16500.0
# ...

# %%
#-----****  10 *********
# cylindernumber 123 and overall price

# %%
df_cars_fil.cylindernumber.unique()
# Out:
# array(['four', 'six', 'five', 'three', 'twelve', 'two', 'eight'],
#       dtype=object)

# %%
df_cy=df_cars_fil[df_cars_fil['cylindernumber'].isin(['one','two','three'])]
df_cy
# Out:
#     car_ID  symboling           CarName fueltype aspiration doornumber  \
# 18      19          2  chevrolet impala      gas        std        two
# 55      56          3         mazda 626      gas        std        two
# 56      57          3         mazda glc      gas        std        two
# 57      58          3     mazda rx-7 gs      gas        std        two
# 58      59          3       mazda glc 4      gas        std        two
#
#       carbody drivewheel enginelocation  wheelbase  ...  enginesize  \
# 18  hatchback        fwd          front       88.4  ...          61
# 55  hatchback        rwd          front       95.3  ...          70
# 56  hatchback        rwd          front       95.3  ...          70
# 57  hatchback        rwd          front       95.3  ...          70
# 58  hatchback        rwd          front       95.3  ...          80
#
#     fuelsystem  boreratio  stroke compressionratio horsepower  peakrpm  \
# ...

# %%
df_cy.cylindernumber.unique()
# Out:
# array(['three', 'two'], dtype=object)

# %%
df_cy[['cylindernumber','price']]
# Out:
#    cylindernumber    price
# 18          three   5151.0
# 55            two  10945.0
# 56            two  11845.0
# 57            two  13645.0
# 58            two  15645.0

# %%
#-------11-------------

# %%
#-----------12---Q12		fuelsystem	boreratio-overall	stroke-overall	compressionratio-overall

# %%
df_cars_fil[['fuelsystem','boreratio','stroke','compressionratio']]
# Out:
#     fuelsystem  boreratio  stroke  compressionratio
# 0         mpfi       3.47    2.68               9.0
# 1         mpfi       3.47    2.68               9.0
# 2         mpfi       2.68    3.47               9.0
# 3         mpfi       3.19    3.40              10.0
# 4         mpfi       3.19    3.40               8.0
# ..         ...        ...     ...               ...
# 200       mpfi       3.78    3.15               9.5
# 201       mpfi       3.78    3.15               8.7
# 202       mpfi       3.58    2.87               8.8
# 203        idi       3.01    3.40              23.0
# 204       mpfi       3.78    3.15               9.5
#
# [205 rows x 4 columns]

# %%
# Q13	cylindernumber	horsepower	peakrpm	citympg	highwaympg	price

# %%
df_13=df_cars_fil[df_cars_fil['cylindernumber'].isin(['one','two','three'])]

# %%
df_13
# Out:
#     car_ID  symboling           CarName fueltype aspiration doornumber  \
# 18      19          2  chevrolet impala      gas        std        two
# 55      56          3         mazda 626      gas        std        two
# 56      57          3         mazda glc      gas        std        two
# 57      58          3     mazda rx-7 gs      gas        std        two
# 58      59          3       mazda glc 4      gas        std        two
#
#       carbody drivewheel enginelocation  wheelbase  ...  enginesize  \
# 18  hatchback        fwd          front       88.4  ...          61
# 55  hatchback        rwd          front       95.3  ...          70
# 56  hatchback        rwd          front       95.3  ...          70
# 57  hatchback        rwd          front       95.3  ...          70
# 58  hatchback        rwd          front       95.3  ...          80
#
#     fuelsystem  boreratio  stroke compressionratio horsepower  peakrpm  \
# ...

# %%
df_13.cylindernumber.unique()
# Out:
# array(['three', 'two'], dtype=object)

# %%
df_13[['cylindernumber','horsepower','peakrpm','citympg','highwaympg','price']]
# Out:
#    cylindernumber  horsepower  peakrpm  citympg  highwaympg    price
# 18          three          48     5100       47          53   5151.0
# 55            two         101     6000       17          23  10945.0
# 56            two         101     6000       17          23  11845.0
# 57            two         101     6000       17          23  13645.0
# 58            two         135     6000       16          23  15645.0
